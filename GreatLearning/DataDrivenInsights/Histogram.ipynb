# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
# plot without any bins
df=pd.read_csv('/GreatLearning/datafiles/data.csv')
plot = sns.histplot(data=df,x="Age")
plt.show()

# %%
# Plot the Histogram of Age Column with bins=10 specified
plot=sns.histplot(data=df,x='Age',bins=10)
plt.show()

# %%
# Plot the histogram of the age column with  binwidth = 5 specified
plot=sns.histplot(data=df,x='Age',binwidth=5)
plt.show()

# %%
plot=sns.histplot(data=df,x='Price')
plt.show()

# %%
plot=sns.histplot(data=df,x='Price',bins=5)
plt.show()

# %%
plot=sns.histplot(data=df,x='Price',bins=5,kde=True)
plt.show()

# %%
plot=sns.boxplot(data=df['Age'])

# %%
plt.show()
plot = sns.boxplot(data=df,x='Age')
plt.show()

# %%
body_style_price_plot = sns.boxplot(data=df,x='Age',y='Price')

# %%
body_style_price_plot = sns.boxplot(data=df,x='Age',y='Price',color='green')

# %%
sns.jointplot(data=df,x='Age',y='Price',color='red')

# %%
sns.violinplot(data=df,x='Age',color='blue')
# Out:
# <Axes: xlabel='Age'>

# %%
import plotly.express as px

# %%
 his = px.histogram(df,x='Age')
 his.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 his = px.histogram(df,x='Age')
#       2 his.show()
#
# NameError: name 'px' is not defined
