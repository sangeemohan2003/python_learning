# %% [markdown]
# Step 1 : Import libraries

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# symboling: Insurance risk rating (-3 to 3)
#
# normalized_losses: Simulated float values
#
# make: Car brands (e.g., Toyota, BMW, Honda, Ford, Audi)
#
# fuel_type: gas or diesel
#
# aspiration: std or turbo
#
# num_of_doors: two or four
#
# body_style: sedan, hatchback, wagon, convertible, hardtop
#
# drive_wheels: fwd, rwd, 4wd
#
# engine_location: front or rear
#
# wheel_base, length, width, height: in inches
#
# curb_weight: in pounds
#
# engine_type: DOHC, OHV, OHC, rotor
#
# num_of_cylinders: three, four, five, six, eight, twelve
#
# engine_size: in cubic inches
#
# fuel_system: mpfi, 2bbl, 1bbl, idi, spdi
#
# bore, stroke: in inches
#
# compression_ratio: float
#
# horsepower: integer
#
# peak_rpm: integer
#
# city_mpg, highway_mpg: integer
#
# price: float in USD

# %% [markdown]
# Step 2 : reading csv file and assign to data frame name df

# %%
df = pd.read_csv('/GreatLearning/datafiles/carEngine.csv')
df.head()
# Out:
#    symboling  normalized_losses    make fuel_type aspiration num_of_doors  \
# 0          2                150  Toyota       gas        std         four
# 1          0                120   Honda       gas        std         four
# 2          1                180     BMW    diesel      turbo          two
# 3         -1                100    Ford       gas        std         four
# 4          3                200    Audi       gas      turbo         four
#
#   body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 0      sedan          fwd           front        97.0  ...          120
# 1  hatchback          fwd           front        96.5  ...          110
# 2      sedan          rwd           front       103.0  ...          180
# 3      wagon          fwd           front       102.0  ...          150
# 4      sedan          4wd           front       105.0  ...          200
#
#    fuel_system  bore  stroke compression_ratio horsepower  peak_rpm city_mpg  \
# ...

# %% [markdown]
# 3 Computer Correlation matrix
#
#
# corr_matrix_name = dataFrameName[['Column1','Column2']].corr()

# %%
#Compute correlation matrix
corr_matrix = df[['wheel_base','curb_weight','engine_size','price']].corr()
# Plotting heat map
plot = sns.heatmap(corr_matrix,annot=True)
plt.show()

# %% [markdown]
# Plotting heat map with cbar= false ; what is cbar???
#
# cbar - is color bar
#
# cbar = False -- Removes the color bar
# cbar = True  -- by default and it adds the color bar

# %%
sns.heatmap(corr_matrix,annot=True,cbar=False)
# Out:
# <Axes: >

# %%
#Annot=False -- >  when it is False, it doens include the correclation numbrers on the box
# By fault - Annot is False

plot= sns.heatmap(corr_matrix,annot=False)

# %%
plot = sns.heatmap(corr_matrix,annot=False,vmin=0,vmax=1) # what is vmin and max ????

# %%
plot = sn.heatmap(corr_matrix,annot=False,cbar=True)

# %%
plot = sns.heatmap(corr_matrix,annot=True,fmt='.2g')

# %%
plot = sns.heatmap(corr_matrix,annot=True,fmt='.1f') # what is fmt - .2g and .1f will do ?

# %% [markdown]
# Other approach
#
# ![image.png](attachment:53b3ad28-b143-4ccd-918b-143e8771db3d.png)
