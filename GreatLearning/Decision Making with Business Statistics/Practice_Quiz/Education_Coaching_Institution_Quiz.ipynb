# %% [markdown]
# Problem Statement:
# Every business makes important decisions from time to time for its growth and sustainability. Suppose an educational coaching institution wants to grow its business. For that, they want to understand the students' performance in a certain test. You have been tasked by the institution to provide them some evidence-based inferences regarding the students that might help them make business decisions. They have randomly collected data about the students' scores in three exams and a variety of personal, social, and economic factors that might have interaction effects upon them. The data is stored in 'students.csv'.
#
#
# Attribute Information:
#
# gender: This is the student's gender; which is either male or female.
#
# race: This is the students' race, which indicates that the student belongs to one of the races from A, B, C, D, and E.
#
# parental_level_of_education: This is the highest educational level attained by the student's parents.
#
# taken_test_preparation_course: This indicates whether the student has taken the test preparation course or not.
#
# maths_score: This is the student's score in the Maths exam.
#
# reading_score: This is the student's score in the English Reading exam.
#
# writing_score: This is the student's score in the English Writing exam.
#
# overall_score: This is the students' average score in the three exams.
#
#
# Kindly go through these guidelines before you attempt the quiz:
# Ensure there is a proper internet connection while taking up the quiz. Any breakup in the connection will automatically submit your quiz.
#
# Only attempt the quiz when you are prepared and have enough time on your hands to finish it. It is strongly recommended that you attempt the quiz after the third mentored learning session. Please ensure you attempt the quiz well before the due date. No extension will be provided for any quiz once the deadline is passed.
#
# The quiz once opened, must be completed within the time frame provided. You CANNOT start the quiz, leave it unattended for an extended period of time and come back later to finish.
#
# No re-attempts will be provided if the quiz gets submitted for any of the above-mentioned reasons.
#
# If you face any other technical issues on Olympus, you should share the screenshot with your Program Manager so that the team can understand and resolve it on priority.

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/Users/mohanrajsubramaniam/PycharmProjects/python_learning/GreatLearning/Decision Making with Business Statistics/Practice_Quiz/students.csv")

# %%
df.info()
df.head()
df.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   gender                         100 non-null    object
#  1   race                           100 non-null    object
#  2   parental_level_of_education    100 non-null    object
#  3   taken_test_preparation_course  100 non-null    object
#  4   maths_score                    100 non-null    int64
#  5   reading_score                  100 non-null    int64
#  6   writing_score                  100 non-null    int64
#  7   overall_score                  100 non-null    float64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 6.4+ KB
#     gender    race parental_level_of_education taken_test_preparation_course  \
# 95    male  Race A            some high school                            no
# ...

# %%
df['maths_score'].mean()
# Out:
# np.float64(68.45)

# %%
df['maths_score'].std()
# Out:
# np.float64(14.240626901420267)

# %%
z_score = (df['maths_score'][4] - df['maths_score'].mean()) / df['maths_score'].std()
print(z_score)
# Out:
# -0.5933727537765388

# %%
df.iloc[4]
# Out:
# gender                                female
# race                                  Race A
# parental_level_of_education      high school
# taken_test_preparation_course             no
# maths_score                               60
# reading_score                             66
# writing_score                             66
# overall_score                           64.0
# Name: 4, dtype: object

# %%
print(df['reading_score'].mean())
reading_ZScore = (df['reading_score'][4] - df['reading_score'].mean()) / df['reading_score'].std()
print(reading_ZScore)
# Out:
# 70.8
# -0.3532986877822522
