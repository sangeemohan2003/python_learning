# %%
# import the important packages
import pandas as pd  # library used for data manipulation and analysis
import numpy as np  # library used for working with arrays
import matplotlib.pyplot as plt  # library for plots and visualizations
import seaborn as sns  # library for visualizations

#%matplotlib inline

import scipy.stats as stats  # this library contains a large number of probability distributions as well as a growing library of statistical functions

# %%
 debuggingData = pd.read_csv("/Users/mohanrajsubramaniam/PycharmProjects/python_learning/GreatLearning/datafiles/debugging.csv")
 debuggingData.shape
 debuggingData.head()
# Out:
#    Bug ID  Time Taken to fix the bug
# 0   12986                       2.42
# 1   12987                       2.03
# 2   12988                       2.74
# 3   12989                       3.21
# 4   12990                       3.40

# %%
plt.hist(debuggingData["Time Taken to fix the bug"], 11, rwidth=0.9, density=True)
# Out:
# (array([0.25755523, 0.21156323, 0.27332392, 0.24704277, 0.2614974 ,
#         0.2431006 , 0.25886929, 0.23915843, 0.26938175, 0.23784437,
#         0.25755523]),
#  array([1.01      , 1.37272727, 1.73545455, 2.09818182, 2.46090909,
#         2.82363636, 3.18636364, 3.54909091, 3.91181818, 4.27454545,
#         4.63727273, 5.        ]),
#  <BarContainer object of 11 artists>)
