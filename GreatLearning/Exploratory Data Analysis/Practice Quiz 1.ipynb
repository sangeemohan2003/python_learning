# %% [markdown]
# ![image.png](attachment:798cadc9-99d8-443e-abaa-61fc2a9602a6.png)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from GreatLearning.DataDrivenInsights.HeatMap_Exercise import corr_matrix

# %%
df = pd.read_csv('/GreatLearning/datafiles/Placement_Data.csv')

# %%
#df.info()

placed_count = (df['status'] == 'Placed').sum()
print("Number of Placed candidates:", placed_count)
# Out:
# Number of Placed candidates: 148

# %%
df.describe()
# Out:
#             ssc_p       hsc_p    degree_p     etest_p       mba_p
# count  215.000000  215.000000  215.000000  215.000000  215.000000
# mean    67.303395   66.333163   66.370186   72.100558   62.278186
# std     10.827205   10.897509    7.358743   13.275956    5.833385
# min     40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     60.600000   60.900000   61.000000   60.000000   57.945000
# 50%     67.000000   65.000000   66.000000   71.000000   62.000000
# 75%     75.700000   73.000000   72.000000   83.500000   66.255000
# max     89.400000   97.700000   91.000000   98.000000   77.890000

# %%
df.head()
# Out:
#   gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0      M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1      M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2      M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3      M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4      M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
#
#   workex  etest_p specialisation  mba_p      status
# 0     No     55.0         Mkt&HR  58.80      Placed
# 1    Yes     86.5        Mkt&Fin  66.28      Placed
# 2     No     75.0        Mkt&Fin  57.80      Placed
# 3     No     66.0         Mkt&HR  59.43  Not Placed
# 4     No     96.8        Mkt&Fin  55.50      Placed

# %%
sns.countplot(data=df, x='hsc_s',hue='status')
# Out:
# <Axes: xlabel='hsc_s', ylabel='count'>

# %%
specialization_counts = df['hsc_s'].value_counts()
print(specialization_counts)
# Out:
# hsc_s
# Commerce    113
# Science      91
# Arts         11
# Name: count, dtype: int64

# %%
corr_matrix = df.corr(numeric_only=True)
print(corr_matrix)
# Out:
#              ssc_p     hsc_p  degree_p   etest_p     mba_p
# ssc_p     1.000000  0.511472  0.538404  0.261993  0.388478
# hsc_p     0.511472  1.000000  0.434206  0.245113  0.354823
# degree_p  0.538404  0.434206  1.000000  0.224470  0.402364
# etest_p   0.261993  0.245113  0.224470  1.000000  0.218055
# mba_p     0.388478  0.354823  0.402364  0.218055  1.000000

# %%
sns.heatmap(data=corr_matrix, annot=True)
# Out:
# <Axes: >

# %%
sns.lineplot(data=df, x='hsc_s', y='degree_p')
# Out:
# <Axes: xlabel='hsc_s', ylabel='degree_p'>

# %%
sns.lineplot(data=df, x='ssc_p', y='hsc_p', hue='status')
# Out:
# <Axes: xlabel='ssc_p', ylabel='hsc_p'>

# %%
sns.boxplot(data=df, x='degree_p', hue='status')
# Out:
# <Axes: xlabel='degree_p'>

# %%
sns.histplot(data=df, x='degree_p', hue='status')
# Out:
# <Axes: xlabel='degree_p', ylabel='Count'>

# %%
sns.boxplot(data=df, x='ssc_p', hue='status')
# Out:
# <Axes: xlabel='ssc_p'>

# %%
sns.barplot(data=df, x='etest_p')
# Out:
# <Axes: xlabel='etest_p'>

# %% [markdown]
# Attempt #1
# Nov 10, 11:25 PM
# Marks: 14
# Question 1
# Correct Answer
# Marks: 1/1
#
# Load the 'Placement_Data.csv' into a Pandas dataframe.
#
# What is the number of "Placed" candidates in the provided dataset?
#
# 148
#
# You Selected
# 67
#
# 140
#
# 48
#
# There are various ways to solve this problem:
#
# Method 1:
#
# We can use the following code to check the shape of data whose status is equal to Placed.
#
# df[df['status']=='Placed'].shape[0]
# Method 2:
#
# It can be counted by using the value_counts:
#
# df['status'].value_counts()
#
# Question 2
# Correct Answer
# Marks: 1/1
#
# Print the statistical summary of the data using the pandas describe() function.
#
# Based on the summary, which of the following statement is true?
#
# A. Student's MBA percentage ranges between 57.945 - 77.89%
#
# B. Students score 66.37% on average in their degree.
#
# Only A
#
# Only B
#
# You Selected
# Neither A nor B
#
# Both A & B
#
# We can generate the statistical summary of the data using the describe function present in the pandas library.
#
# df.describe()
# Based on the generated summary we can observe:
#
# MBA percentage('mba_p') of the students ranges between 51.21 - 77.89.
# Students score 66.37% on average in their degree.
#
# Question 3
# Incorrect Answer
# Marks: 0/1
#
# Which one of the following graphs is the distribution plot of Eligibility test?
# Incorrect1.PNG
# Incorrect2.PNG
# correct (1).PNG
# Correct Option
# Incorrect3.PNG
# You Selected
# The above graph is a histogram, to generate a histogram we can use the histplot functionLinks to an external site. of the Seaborn library.
#
# histplot() helps us to visualize the distribution of the variable
#
# sns.histplot(x = 'etest_p', data = df)
#
# Question 4
# Correct Answer
# Marks: 1/1
#
# What will be the output of the following code?
#
# df = pd.read_csv('Placement_Data.csv') # Load the dataset
# sns.countplot(x = 'hsc_s', data = df, hue = 'status')
# incorrect1 (6).PNG
# You Selected
# correct (6).PNG
# incorrect2 (6).PNG
# incorrect3 (6).PNG
# Here, the above code generates a count plot( bar graph) which categorizes the students on the x-axis based on their specialization in  Higher Secondary Education(hsc_s). By using hue, we further categorize the plot and extract the student's employment status(hue = 'status').
#
# Question 5
# Correct Answer
# Marks: 1/1
#
# Which of the following graph is of student's specialization in Higher Secondary Education?
# incorrect1 (1).PNG
# incorrect2 (1).PNG
# incorrect3 (1).PNG
# correct.PNG
# You Selected
# The above plotted graphs are countplots. Countplot for student's specialization in Higher Secondary Education can be plotted using the following code:
#
# sns.countplot(x = 'hsc_s', data = df)
# We can also plot the graph by using catplot with kind = ‘count’
#
# sns.catplot(data = df, x = 'hsc_s', kind = 'count')
#
#
#
# Question 6
# Correct Answer
# Marks: 1/1
#
# Which among the following columns have the highest correlation with each other?
# Employability test percentage and MBA percentage
#
# Secondary Education percentage and Degree percentage
#
# You Selected
# Higher Secondary Education percentage and Degree percentage
#
# Higher Secondary Education percentage and Secondary Education percentage
#
# We can find the correlation of the numerical columns of the data using the following code:
#
# sns.heatmap(df.corr(), annot = True, cmap='YlGnBu')
# It generates a heatmap that will help plot the correlation among numerical data with color mapped index.
#
# download (11).png
#
#
# Question 7
# Correct Answer
# Marks: 1/1
#
# Which one of the following is the boxplot visualization of students' degree percentage and their specialization in Higher Secondary Education?
# incorrect2 (2).PNG
# incorrect1 (2).PNG
# correct (2).PNG
# You Selected
# incorrect3 (2).PNG
# A box plot (or box-and-whisker plot) shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable.
#
# Boxplot can be created using boxplot function:
#
# sns.boxplot(x ='degree_p', y = 'hsc_s', data = df )
# The same can be achieved using the catplot:
#
# sns.catplot(x ='degree_p', y = 'hsc_s', data = df, kind = 'box')
#
# Question 8
# Correct Answer
# Marks: 1/1
#
# Plot a graph between Secondary Education percentage and Higher Secondary Education percentage and categorize them based on the employment status. (hue = 'status')
#
# Select True/False for the following statement:
#
# Based on the graph plotted, the best fit line for Placed students is plotted higher than the best fit line for the not Placed students.
#
# True
#
# You Selected
# False
#
# Best fit lines can be generated in the seaborn's lmplot functionLinks to an external site.. When we plot the graph using the following command:
#
# sns.lmplot(x = 'ssc_p', y = 'hsc_p',hue = 'status', data = df)
# We can observe that the best fit line for Placed students is plotted higher than the best fit line for the not Placed students.
#
# download (12).png
#
#
# Question 9
# Correct Answer
# Marks: 1/1
#
# Which plot among the following is of degree percentage with hue as status ?
# download (1).png
# download (2).png
# download.png
# You Selected
# download (3).png
# The correct graph can be generated using the following command:
#
# sns.histplot(data = df,x="degree_p",kde= True,hue = 'status')
# plt.legend(["Not Placed", "Placed"])
#
# Question 10
# Correct Answer
# Marks: 1/1
#
# Select True/False for the following statement:
#
# 75% of not placed students have their Secondary Education percentage less than 65%.
#
# True
#
# You Selected
# False
#
# To understand this relationship, we can plot a boxplot using the following code:
#
# sns.boxplot(x = 'ssc_p', y = 'status', data = df)
# download (10).png
#
#
#
# As we can observe from the graph, 75% of not placed students have their Secondary Education percentage less than 65%.
#
#
# Question 11
# Correct Answer
# Marks: 1/1
#
# Which of the following is used to set the color mapped to the data values of heatmap?
# corr
#
# cmap
#
# You Selected
# map
#
# color
#
# Heatmaps can be generated using the following code:
#
# sns.heatmap(df.corr(), annot = True, cmap = 'YlGnBu')
# Here annot is used to print correlation on top of the colored boxes,
#
# cmap : is used for mapping data values to color space. If not provided, the default will depend on whether center is set.
#
# Some common cmap’s used for mapping are: ‘YlGnBu’[Stands for Yellow, Green and Blue], ‘Blues’, ‘Greens’ and ‘Reds’,
#
#
# Question 12
# Correct Answer
# Marks: 1/1
#
# Following is a graph of degree percentage of all the disciplines categorized for placed and not placed students.
#
# download (13).png
#
# Select True/False for the following statement:
#
# Based on the graph, 50% of students that are placed have a higher degree percentage when compared with not placed students.
#
# True
#
# You Selected
# False
#
# Based on the above graph, we can observe that all the median line for placed students is above the median line of the not placed students. This indicates that 50% of students that are placed have a higher degree percentage when compared with not placed students. (Since 50% of data lies above the median line.)
#
# Question 13
# Correct Answer
# Marks: 1/1
#
# Following is a violin plot of students with specialization and their degree percentage.
#
# download (15).png
#
# Select True/False for the following statement:
#
# 75% of students who opted for Marketing & HR and Marketing & Finance have their degree percentage below 80%
#
# True
#
# You Selected
# False
#
# As we can observe from the violin plot above, the thick black line for Mkt&HR and Mkt&Fin ends before 80% on the degree percentage scale, meaning that 75% of students have their degree percentage less than 80%.
#
# Question 14
# Correct Answer
# Marks: 1/1
#
# Plot a hexplot (use jointplot() with kind='hex') for degree percentage and Secondary Education percentage.
#
# Select True/False for the following statement:
#
# A. Students that score between 60-70% in Secondary Education(ssc) are more likely to score in the range of 60-70% in degree.
#
# B. The Secondary Education percentage is a highly right skewed data.
#
# Only A
#
# You Selected
# Only B
#
# Neither A nor B
#
# Both A & B
#
# We can plot a pairplot for degree percentage and Secondary Education percentage using seaborn's jointplot function. Here, kind = ‘hex’ uses hexagonal bins to represent data – the darker the color, the higher the number of data points in that bin.
#
# We can plot the hex pairplot using the following code:
#
# sns.jointplot(  x = df['ssc_p'], y = df['degree_p'], kind = 'hex')
# download (17)-1.png
#
# From the plot, we can see that the Secondary Education percentage for range 60 to 70 and Degree percentage for a range of 60 to 70 is of the darkest shade. Meaning, students who score between 60-70% in ssc are more likely to score in the range of 60-70% in degree.
#
# Also, the Secondary Education percentage distribution is almost a normal distribution.
#
#
# Question 15
# Correct Answer
# Marks: 1/1
#
# Select True/False for the following statement:
#
# A. Employability test percentage data is a right-skewed distribution.
#
# B. Highest percentage scored in the Employability test percentage is 98%.
#
# Only A
#
# Only B
#
# Neither A nor B
#
# Both A & B
#
# You Selected
# We can plot the distribution of 'etest_p' using the following code:
#
# sns.histplot(df['etest_p'], kde= True)
# As we can observe, the data is right skewed and the maximum 'etest_p' percentage is 98%
#
# download (19).png
#
# To calculate the maximum percentage scored in the Employability test, we can use the max function of pandas library.
#
# df['etest_p'].max()
