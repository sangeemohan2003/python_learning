# %%
thislist = ["apple", "banana", "cherry"]
print(thislist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
# Replace
thislist.append("orange")
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
thislist.pop(1)
# Out:
# 'banana'

# %%
thislist
# Out:
# ['apple', 'cherry', 'orange']

# %%
tupleExample = ("apple", "banana", "cherry")
print(tupleExample)
# Out:
# ('apple', 'banana', 'cherry')

# %%
for index in tupleExample:
    print(index)
# Out:
# apple
# banana
# cherry

# %%
# Out:
# True
